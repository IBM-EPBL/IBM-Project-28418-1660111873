# %%
import pandas as pd

# %%
two data structures - series and data frame
a=[1,2,3,4,5]
# Out:
#   File "<ipython-input-7-4b32126a4b5d>", line 1
#     two data structures - series and data frame
#            ^
# SyntaxError: invalid syntax
